# %%
import pandas as pd

file_path = r"C:\Users\José Martins\Desktop\LABS and PROJECTS\week_proj_ML\w7_Project\data\cars.csv"

df = pd.read_csv(file_path)
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %% [markdown]
# ## Missing values

# %%
missing_values = df.isnull().sum()

#print("Missing values per column:")
#print(missing_values)

# %%
unique_values = df['Market Category'].unique()
#print("Unique values in 'Market Category':")
#print(unique_values)

# %%
df_cleaned = df.dropna(subset='Market Category')

# %%
#df_cleaned.isnull().sum()

# %%
def missingvalues_df(df):
    
    #drop row with missing values on Market Catefory
    df.dropna(subset='Market Category',inplace = True)
    
    # columns with mean
    df['Engine HP'].fillna(df['Engine HP'].mean(), inplace=True)
    df['Engine Cylinders'].fillna(df['Engine Cylinders'].mean(), inplace=True)

    # column with mode
    df['Number of Doors'].fillna(df['Number of Doors'].mode().iloc[0], inplace=True)
    return df

# %%
df_cars = missingvalues_df(df)

# %%
#df_cleaned.isnull().sum()

# %%
#df_cleaned.isnull().sum()

# %%
df_cars
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
#csv_file_path = r'C:\Users\José Martins\Desktop\LABS and PROJECTS\week_proj_ML\w7_Project\data\cars_clean.csv'

#df_cars.to_csv(csv_file_path, index=False)

# %%
#df_cars.dtypes

# %%
#df_cars['Make'].value_counts()

# %%
df_cars['Driven_Wheels'].value_counts()
# Out:
# Driven_Wheels
# front wheel drive    2920
# rear wheel drive     2431
# all wheel drive      2175
# four wheel drive      646
# Name: count, dtype: int64

# %% [markdown]
# ## Transmission Type

# %%
cars_object_columns = df_cars.select_dtypes(include = [object]).columns # dummies

df_cars_object = df_cars.select_dtypes(include = [object])

df_cars_object
# Out:
#           Make       Model                Engine Fuel Type Transmission Type  \
# 0          BMW  1 Series M     premium unleaded (required)            MANUAL
# 1          BMW    1 Series     premium unleaded (required)            MANUAL
# 2          BMW    1 Series     premium unleaded (required)            MANUAL
# 3          BMW    1 Series     premium unleaded (required)            MANUAL
# 4          BMW    1 Series     premium unleaded (required)            MANUAL
# ...        ...         ...                             ...               ...
# 11909    Acura         ZDX     premium unleaded (required)         AUTOMATIC
# 11910    Acura         ZDX     premium unleaded (required)         AUTOMATIC
# 11911    Acura         ZDX     premium unleaded (required)         AUTOMATIC
# 11912    Acura         ZDX  premium unleaded (recommended)         AUTOMATIC
# 11913  Lincoln      Zephyr                regular unleaded         AUTOMATIC
#
# ...

# %%
df_cars_dummies = pd.get_dummies(df_cars, columns = cars_object_columns)

# %%
df_cars_dummies
# Out:
#        Year  Engine HP  Engine Cylinders  Number of Doors  highway MPG  \
# 0      2011      335.0               6.0              2.0           26
# 1      2011      300.0               6.0              2.0           28
# 2      2011      300.0               6.0              2.0           28
# 3      2011      230.0               6.0              2.0           28
# 4      2011      230.0               6.0              2.0           28
# ...     ...        ...               ...              ...          ...
# 11909  2012      300.0               6.0              4.0           23
# 11910  2012      300.0               6.0              4.0           23
# 11911  2012      300.0               6.0              4.0           23
# 11912  2013      300.0               6.0              4.0           23
# 11913  2006      221.0               6.0              4.0           26
#
#        city mpg  Popularity   MSRP  Make_Acura  Make_Alfa Romeo  ...  \
# ...
